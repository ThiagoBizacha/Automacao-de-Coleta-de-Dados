# %% [markdown]
# # API RAPID AMAZON

# %% [markdown]
# ### Endpoints Best Sellers AMAZON

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime
import logging

# Configurar o logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("amazon_data.log"),
        logging.StreamHandler()
    ]
)

# Carregar variáveis de ambiente do arquivo .env
load_dotenv()

# Obter a chave da API a partir das variáveis de ambiente
rapidapi_key = os.getenv("RAPIDAPI_KEY")

# Dicionário de categorias
categories_dict = {
    "Alle afdelingen": "aps",
    "Amazon Warehouse": "warehouse-deals",
    "Amazon-apparaten": "amazon-devices",
    "Auto en motor": "automotive",
    "Babyproducten": "baby",
    "Beauty en persoonlijke verzorging": "beauty",
    "Black Friday": "black-friday",
    "Boeken": "stripbooks",
    "Cadeaubonnen": "gift-cards",
    "Cd's en lp's": "popular",
    "Elektronica": "electronics",
    "Films en tv": "dvd",
    "Gezondheid en persoonlijke verzorging": "hpc",
    "Huisdierbenodigdheden": "pets",
    "Kantoorproducten": "office-products",
    "Kindle Store": "digital-text",
    "Kleding, schoenen en sieraden": "fashion",
    "Klussen en gereedschap": "home-improvement",
    "Levensmiddelen": "grocery",
    "Muziekinstrumenten": "mi",
    "Overig": "misc",
    "Prime Video": "instant-video",
    "Software": "software",
    "Speelgoed en spellen": "toys",
    "Sport en outdoor": "sports",
    "Tuin, terras en gazon": "outdoor",
    "Videogames": "videogames",
    "Wonen en keuken": "home",
    "Zakelijk, industrie en wetenschap": "industrial"
}

# Lista de categorias (category_id)
categories = list(categories_dict.values())

# Definir a URL da API
url = "https://real-time-amazon-data.p.rapidapi.com/best-sellers"

# Definir os cabeçalhos da solicitação
headers = {
    "x-rapidapi-key": rapidapi_key,
    "x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com"
}

# Inicializar lista para armazenar DataFrames
all_dataframes = []

# Função para processar cada categoria
def process_category(category_id, category_name):
    querystring = {"category": category_id, "type": "BEST_SELLERS", "page": "1", "country": "NL"}
    
    try:
        # Fazer a solicitação à API
        response = requests.get(url, headers=headers, params=querystring)
        response.raise_for_status()  # Levantar exceção para códigos de erro HTTP

        data = response.json()

        # Extrair a data atual
        today = datetime.today().strftime('%Y-%m-%d')

        # Normalizar os dados JSON e converter para DataFrame
        best_sellers = data['data']['best_sellers']
        df = pd.json_normalize(best_sellers)

        # Verificar se a coluna 'product_price' existe e processar
        if 'product_price' in df.columns:
            # Remover o símbolo da moeda euro do campo "product_price" e converter para float
            df['product_price'] = df['product_price'].str.replace('€', '').str.replace(',', '.').str.strip().astype(float)
        else:
            # Adicionar a coluna 'product_price' com valores NaN se não existir
            df['product_price'] = float('nan')

        # Adicionar a coluna "name_category", "category_id" e "date" como as últimas colunas
        df.insert(len(df.columns), 'name_category', category_name)
        df.insert(len(df.columns), 'category_id', category_id)
        df.insert(len(df.columns), 'date', today)

        # Adicionar DataFrame à lista
        all_dataframes.append(df)

        # Definir o nome do arquivo XLSX individual
        file_name = f"{category_name}_Amazon_bestseller_{today}.xlsx"

        # Definir o diretório de salvamento com as duas pastas adicionais
        save_directory = os.path.join(os.getcwd(), 'output', 'rapid_amazon_best_sellers')

        # Certifique-se de que o diretório existe
        os.makedirs(save_directory, exist_ok=True)

        # Definir o caminho completo do arquivo
        file_path = os.path.join(save_directory, file_name)

        # Salvar o DataFrame em um arquivo Excel individual
        df.to_excel(file_path, index=False)

        logging.info(f"Arquivo salvo como: {file_name}")

    except requests.exceptions.HTTPError as http_err:
        logging.error(f"HTTP error ao processar a categoria {category_name}: {http_err}")
    except Exception as err:
        logging.error(f"Erro ao processar a categoria {category_name}: {err}")

# Processar cada categoria na lista
for name_category, category_id in categories_dict.items():
    process_category(category_id, name_category)

# Concatenar todos os DataFrames em um único DataFrame
if all_dataframes:
    final_df = pd.concat(all_dataframes, ignore_index=True)

    # Definir o nome do arquivo XLSX final
    final_file_name = f"All_Categories_Amazon_bestseller_{datetime.today().strftime('%Y-%m-%d')}.xlsx"
    final_file_path = os.path.join(os.getcwd(), 'output', 'rapid_amazon_best_sellers', final_file_name)

    # Salvar o DataFrame final em um arquivo Excel
    final_df.to_excel(final_file_path, index=False)

    logging.info(f"Arquivo XLSX final salvo como: {final_file_path}")
else:
    logging.warning("Nenhum dado foi processado para salvar no arquivo final.")
# Out:
# 2024-08-09 10:58:12,030 - ERROR - HTTP error ao processar a categoria Alle afdelingen: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=aps&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,072 - ERROR - HTTP error ao processar a categoria Amazon Warehouse: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=warehouse-deals&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,124 - ERROR - HTTP error ao processar a categoria Amazon-apparaten: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=amazon-devices&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,175 - ERROR - HTTP error ao processar a categoria Auto en motor: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=automotive&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,219 - ERROR - HTTP error ao processar a categoria Babyproducten: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=baby&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,264 - ERROR - HTTP error ao processar a categoria Beauty en persoonlijke verzorging: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=beauty&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,305 - ERROR - HTTP error ao processar a categoria Black Friday: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=black-friday&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,341 - ERROR - HTTP error ao processar a categoria Boeken: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=stripbooks&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,385 - ERROR - HTTP error ao processar a categoria Cadeaubonnen: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=gift-cards&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,426 - ERROR - HTTP error ao processar a categoria Cd's en lp's: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=popular&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,465 - ERROR - HTTP error ao processar a categoria Elektronica: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=electronics&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,509 - ERROR - HTTP error ao processar a categoria Films en tv: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=dvd&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,545 - ERROR - HTTP error ao processar a categoria Gezondheid en persoonlijke verzorging: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=hpc&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,586 - ERROR - HTTP error ao processar a categoria Huisdierbenodigdheden: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=pets&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,641 - ERROR - HTTP error ao processar a categoria Kantoorproducten: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=office-products&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,697 - ERROR - HTTP error ao processar a categoria Kindle Store: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=digital-text&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,740 - ERROR - HTTP error ao processar a categoria Kleding, schoenen en sieraden: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=fashion&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,774 - ERROR - HTTP error ao processar a categoria Klussen en gereedschap: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=home-improvement&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,819 - ERROR - HTTP error ao processar a categoria Levensmiddelen: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=grocery&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,861 - ERROR - HTTP error ao processar a categoria Muziekinstrumenten: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=mi&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,906 - ERROR - HTTP error ao processar a categoria Overig: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=misc&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:12,965 - ERROR - HTTP error ao processar a categoria Prime Video: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=instant-video&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,009 - ERROR - HTTP error ao processar a categoria Software: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=software&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,048 - ERROR - HTTP error ao processar a categoria Speelgoed en spellen: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=toys&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,091 - ERROR - HTTP error ao processar a categoria Sport en outdoor: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=sports&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,129 - ERROR - HTTP error ao processar a categoria Tuin, terras en gazon: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=outdoor&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,159 - ERROR - HTTP error ao processar a categoria Videogames: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=videogames&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,200 - ERROR - HTTP error ao processar a categoria Wonen en keuken: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=home&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,247 - ERROR - HTTP error ao processar a categoria Zakelijk, industrie en wetenschap: 429 Client Error: Too Many Requests for url: https://real-time-amazon-data.p.rapidapi.com/best-sellers?category=industrial&type=BEST_SELLERS&page=1&country=NL
# 2024-08-09 10:58:13,248 - WARNING - Nenhum dado foi processado para salvar no arquivo final.
